# %%
# !git clone https://github.com/Sanket-DataEnt/groot.git
# Out:
# Cloning into 'groot'...
# remote: Enumerating objects: 484, done.
# remote: Counting objects: 100% (64/64), done.
# remote: Compressing objects: 100% (47/47), done.
# remote: Total 484 (delta 40), reused 34 (delta 17), pack-reused 420
# Receiving objects: 100% (484/484), 43.30 MiB | 31.40 MiB/s, done.
# Resolving deltas: 100% (293/293), done.

# %%
# %cd /content/groot/Transformer
# Out:
# /content/groot/Transformer

# %%
! ls
# Out:
# config.py  dataset.py  model.py  train.ipynb  train.py

# %%
# !pip install datasets tokenizers torchmetrics tensorboardX -q
# Out:
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 519.3/519.3 kB 5.9 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.8/7.8 MB 20.7 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 763.4/763.4 kB 29.3 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 101.7/101.7 kB 10.6 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 115.3/115.3 kB 11.8 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 194.1/194.1 kB 20.2 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 134.8/134.8 kB 15.1 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 268.8/268.8 kB 23.9 MB/s eta 0:00:00

# %%
from config import get_config

cfg = get_config()
cfg['batch_size'] = 6
cfg['preload'] = None
cfg['num_epochs'] = 30

# %%
from train import train_model
train_model(cfg)
# Out:
# Using device:  cuda
# ...
# Generating train split:   0%|          | 0/32332 [00:00<?, ? examples/s]
# Max length of source sentence: 309
# Max length of target sentence: 274
# Processing Epoch 00:  75%|███████▍  | 3616/4850 [20:16<06:55,  2.97it/s, loss=6.240]
